# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
def uniform_draw():
    theta = np.random.uniform(0, 2.0 * np.pi)
    r_squared = np.random.uniform(0, 1.0)
    x = np.sqrt(r_squared) * np.cos(theta)
    y = np.sqrt(r_squared) * np.sin(theta)
    return x, y

def uniform_drawv2():
    dist = np.random.uniform(0, 1.0)
    r_squared = np.random.uniform(0, 1.0)
    x = np.random.uniform(0, 1.0)
    y = 
    return x, y

# %%
N = 3000
X = []; Y = []
plt.figure(figsize=(5, 5))
for _ in range(N):
    x, y = uniform_drawv2()
    X.append(x)
    Y.append(y)
plt.scatter(X, Y, c='r')
plt.show()
